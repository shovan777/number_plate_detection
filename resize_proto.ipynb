# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os
from os.path import join
import numpy as np
from scipy import ndimage
from matplotlib import pyplot as plt
import cv2
import numpy as np

# %%
img_dir_path = "data/"
new_size_h = 512
new_size_w = 512

# %%
img_paths = os.listdir(path=img_dir_path)
# img_path = list()

# %%
for img_path in img_paths:
#     img_path.append(join(img_dir_path, img))
    img_absolute_path = join(img_dir_path, img_path)
    img = cv2.imread(img_absolute_path)
    print(img_absolute_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = cv2.resize(img, (new_size_w, new_size_h))
#     img = img.astype(np.float32)
#     img /= 255
    cv2.imwrite(img_absolute_path, img)
#     plt.imshow(plt.imread(img_absolute_path))
# Out:
# data/IMG_20180809_105132.jpg

# %%
print
